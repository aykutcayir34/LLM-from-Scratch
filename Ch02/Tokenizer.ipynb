# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tiktoken

# %%
tokenizer = tiktoken.get_encoding("gpt2")

# %%
print(tokenizer.encode("Hello World!"))
# Out:
# [15496, 2159, 0]

# %%
tokenizer.decode([15496, 2159, 0])
# Out:
# 'Hello World!'
